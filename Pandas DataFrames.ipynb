# %% [markdown]
# ### Creating a dataframe

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "Population":[23.44,54.22,77.29,88.82,32.67,66.66,777.77],
    "GDP":[18273,217278,38283,7446,73156,5471,7277],
    "Surface Area":[210,17317,8318,6573,81297,767,878],
    "HDI":[0.912,0.721,0.221,0.887,0.22,0.443,0.412],
    "Continent":["America","Europe","Europe","Asia","America","Africa","Europe"]
},columns=["Population","GDP","Surface Area","HDI","Continent"])

# %% [markdown]
# #### To view your DataFrame

# %%
df
# Out:
#    Population     GDP  Surface Area    HDI Continent
# 0       23.44   18273           210  0.912   America
# 1       54.22  217278         17317  0.721    Europe
# 2       77.29   38283          8318  0.221    Europe
# 3       88.82    7446          6573  0.887      Asia
# 4       32.67   73156         81297  0.220   America
# 5       66.66    5471           767  0.443    Africa
# 6      777.77    7277           878  0.412    Europe

# %% [markdown]
# #### Similar to series we can assign an index to a DataFrame

# %%
df.index = ["Canada","France","Germany","Thailand","Cuba","South Africa","Russia"]

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent
# Canada             23.44   18273           210  0.912   America
# France             54.22  217278         17317  0.721    Europe
# Germany            77.29   38283          8318  0.221    Europe
# Thailand           88.82    7446          6573  0.887      Asia
# Cuba               32.67   73156         81297  0.220   America
# South Africa       66.66    5471           767  0.443    Africa
# Russia            777.77    7277           878  0.412    Europe

# %% [markdown]
# #### DataFrame info tools

# %%
df.info() #give info about structure of your DataFrame 
          #so you can find null/invalid values, Types, etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to Russia
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# dtype: int64

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %% [markdown]
# #### To get summary statistics for numeric values in your table

# %%
df.describe()
# Out:
#        Population            GDP  Surface Area       HDI
# count    7.000000       7.000000      7.000000  7.000000
# mean   160.124286   52454.857143  16480.000000  0.545143
# std    273.346705   76636.333266  29216.846236  0.294766
# min     23.440000    5471.000000    210.000000  0.220000
# 25%     43.445000    7361.500000    822.500000  0.316500
# 50%     66.660000   18273.000000   6573.000000  0.443000
# 75%     83.055000   55719.500000  12817.500000  0.804000
# max    777.770000  217278.000000  81297.000000  0.912000

# %%
df.head() #Gives first five columns of you DataFrame
# Out:
#           Population     GDP  Surface Area    HDI Continent
# Canada         23.44   18273           210  0.912   America
# France         54.22  217278         17317  0.721    Europe
# Germany        77.29   38283          8318  0.221    Europe
# Thailand       88.82    7446          6573  0.887      Asia
# Cuba           32.67   73156         81297  0.220   America

# %%
df.tail() #Gives last five columns of you DataFrame
# Out:
#               Population    GDP  Surface Area    HDI Continent
# Germany            77.29  38283          8318  0.221    Europe
# Thailand           88.82   7446          6573  0.887      Asia
# Cuba               32.67  73156         81297  0.220   America
# South Africa       66.66   5471           767  0.443    Africa
# Russia            777.77   7277           878  0.412    Europe

# %%
population = df["Population"]

# %%
population.min(),population.max()
# Out:
# (23.44, 777.77)

# %%
population.sum()
# Out:
# 1120.87

# %%
len(population)
# Out:
# 7

# %%
population.sum()/len(population)
# Out:
# 160.1242857142857

# %%
population.quantile(0.25) #25 quartile
# Out:
# 43.445

# %%
population.mean()
# Out:
# 160.1242857142857

# %%
population.quantile([0.2,0.4,0.6,0.8,1])
# Out:
# 0.2     36.980
# 0.4     59.196
# 0.6     73.038
# 0.8     86.514
# 1.0    777.770
# Name: Population, dtype: float64

# %%
df.head()
# Out:
#           Population     GDP  Surface Area    HDI Continent
# Canada         23.44   18273           210  0.912   America
# France         54.22  217278         17317  0.721    Europe
# Germany        77.29   38283          8318  0.221    Europe
# Thailand       88.82    7446          6573  0.887      Asia
# Cuba           32.67   73156         81297  0.220   America

# %%
df.groupby(["GDP"]).mean()
# Out:
#         Population  Surface Area    HDI
# GDP
# 5471         66.66         767.0  0.443
# 7277        777.77         878.0  0.412
# 7446         88.82        6573.0  0.887
# 18273        23.44         210.0  0.912
# 38283        77.29        8318.0  0.221
# 73156        32.67       81297.0  0.220
# 217278       54.22       17317.0  0.721

# %%
df["count"]=1
df.groupby(["Continent"]).count()["count"]
# Out:
# Continent
# Africa     1
# America    2
# Asia       1
# Europe     3
# Name: count, dtype: int64

# %% [markdown]
# ### Indexing, Selection and Slicing

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %% [markdown]
# ### loc and iloc (Remember)
# #### loc let's you select by index and iloc let's you select by sequential position i.e. first row last row, etc
# #### df lets you select by column

# %%
df.loc["Canada"]
# Out:
# Population        23.44
# GDP               18273
# Surface Area        210
# HDI               0.912
# Continent       America
# count                 1
# Name: Canada, dtype: object

# %%
df.iloc[0]
# Out:
# Population        23.44
# GDP               18273
# Surface Area        210
# HDI               0.912
# Continent       America
# count                 1
# Name: Canada, dtype: object

# %%
df["Population"] #selecting entire column
# Out:
# Canada           23.44
# France           54.22
# Germany          77.29
# Thailand         88.82
# Cuba             32.67
# South Africa     66.66
# Russia          777.77
# Name: Population, dtype: float64

# %% [markdown]
# #### Here all the results are in series

# %%
df.loc["Canada":"Cuba"]
# Out:
#           Population     GDP  Surface Area    HDI Continent  count
# Canada         23.44   18273           210  0.912   America      1
# France         54.22  217278         17317  0.721    Europe      1
# Germany        77.29   38283          8318  0.221    Europe      1
# Thailand       88.82    7446          6573  0.887      Asia      1
# Cuba           32.67   73156         81297  0.220   America      1

# %%
df.loc["Canada":"Cuba","Population"]
# Out:
# Canada      23.44
# France      54.22
# Germany     77.29
# Thailand    88.82
# Cuba        32.67
# Name: Population, dtype: float64

# %%
df.loc["Canada":"Cuba",["Population","GDP"]]
# Out:
#           Population     GDP
# Canada         23.44   18273
# France         54.22  217278
# Germany        77.29   38283
# Thailand       88.82    7446
# Cuba           32.67   73156

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %% [markdown]
# #### Similarly for iloc

# %%
df.iloc[0:3]
# Out:
#          Population     GDP  Surface Area    HDI Continent  count
# Canada        23.44   18273           210  0.912   America      1
# France        54.22  217278         17317  0.721    Europe      1
# Germany       77.29   38283          8318  0.221    Europe      1

# %%
df.iloc[[0,1,3]]
# Out:
#           Population     GDP  Surface Area    HDI Continent  count
# Canada         23.44   18273           210  0.912   America      1
# France         54.22  217278         17317  0.721    Europe      1
# Thailand       88.82    7446          6573  0.887      Asia      1

# %%
df.iloc[0:3,0]
# Out:
# Canada     23.44
# France     54.22
# Germany    77.29
# Name: Population, dtype: float64

# %%
df.iloc[0:3,[0,1]]
# Out:
#          Population     GDP
# Canada        23.44   18273
# France        54.22  217278
# Germany       77.29   38283

# %% [markdown]
# ### Conditional Selection

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %%
df["Population"]>70
# Out:
# Canada          False
# France          False
# Germany          True
# Thailand         True
# Cuba            False
# South Africa    False
# Russia           True
# Name: Population, dtype: bool

# %%
df.loc[df["Population"]>70]
# Out:
#           Population    GDP  Surface Area    HDI Continent  count
# Germany        77.29  38283          8318  0.221    Europe      1
# Thailand       88.82   7446          6573  0.887      Asia      1
# Russia        777.77   7277           878  0.412    Europe      1

# %%
df.loc[df["Population"]>70,["Population","GDP"]]
# Out:
#           Population    GDP
# Germany        77.29  38283
# Thailand       88.82   7446
# Russia        777.77   7277

# %%
df.head()
# Out:
#           Population     GDP  Surface Area    HDI Continent  count
# Canada         23.44   18273           210  0.912   America      1
# France         54.22  217278         17317  0.721    Europe      1
# Germany        77.29   38283          8318  0.221    Europe      1
# Thailand       88.82    7446          6573  0.887      Asia      1
# Cuba           32.67   73156         81297  0.220   America      1

# %%
df.loc[(df["Population"]>70) & (df["HDI"]>0.5)]
# Out:
#           Population   GDP  Surface Area    HDI Continent  count
# Thailand       88.82  7446          6573  0.887      Asia      1

# %%
df.loc[(df["Population"]>70) | (df["HDI"]>0.5)]
# Out:
#           Population     GDP  Surface Area    HDI Continent  count
# Canada         23.44   18273           210  0.912   America      1
# France         54.22  217278         17317  0.721    Europe      1
# Germany        77.29   38283          8318  0.221    Europe      1
# Thailand       88.82    7446          6573  0.887      Asia      1
# Russia        777.77    7277           878  0.412    Europe      1

# %%
df.loc[df["Continent"].str.contains("Europe")]
# To get reverse of this just add (~)
#df.loc[~df["Continent"].str.contains("Europe")]
# Out:
#          Population     GDP  Surface Area    HDI Continent  count
# France        54.22  217278         17317  0.721    Europe      1
# Germany       77.29   38283          8318  0.221    Europe      1
# Russia       777.77    7277           878  0.412    Europe      1

# %% [markdown]
# ### Using regex
# learn regex

# %%
import re #regular expressions

df.loc[df["Continent"].str.contains("europe|asia",flags=re.I,regex=True)]
#Here flags=re.I ignores case sensitivity
# Out:
#           Population     GDP  Surface Area    HDI Continent  count
# France         54.22  217278         17317  0.721    Europe      1
# Germany        77.29   38283          8318  0.221    Europe      1
# Thailand       88.82    7446          6573  0.887      Asia      1
# Russia        777.77    7277           878  0.412    Europe      1

# %% [markdown]
# ### Drop (i.e. drop x values and give the others)

# %%
df.drop("Canada") #here we aren't actually removing values as
                  #these operations are all immutable 
                  #i.e. do not change the DataFrame as 99% of Pandas operations are immutable
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %%
df.drop(["Canada","Cuba"])
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %%
#you can also drop columns
df.drop(columns=["Surface Area","HDI"])
# Out:
#               Population     GDP Continent  count
# Canada             23.44   18273   America      1
# France             54.22  217278    Europe      1
# Germany            77.29   38283    Europe      1
# Thailand           88.82    7446      Asia      1
# Cuba               32.67   73156   America      1
# South Africa       66.66    5471    Africa      1
# Russia            777.77    7277    Europe      1

# %% [markdown]
# ### Operations

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %%
df[["Population","GDP"]]/100
# Out:
#               Population      GDP
# Canada            0.2344   182.73
# France            0.5422  2172.78
# Germany           0.7729   382.83
# Thailand          0.8882    74.46
# Cuba              0.3267   731.56
# South Africa      0.6666    54.71
# Russia            7.7777    72.77

# %% [markdown]
# #### Performing operation in a bunch using series

# %%
remove = pd.Series([-10,-0.2],index=["Population","GDP"])
remove
# Out:
# Population   -10.0
# GDP           -0.2
# dtype: float64

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %%
df[["Population","GDP"]]+remove
# Out:
#               Population       GDP
# Canada             13.44   18272.8
# France             44.22  217277.8
# Germany            67.29   38282.8
# Thailand           78.82    7445.8
# Cuba               22.67   73155.8
# South Africa       56.66    5470.8
# Russia            767.77    7276.8

# %% [markdown]
# ### Modifying DataFrame
# (whenever you have "=" symbol you are modifying the DataFrame
# && Use inplace = True to permanently change)
# #### Adding a new column

# %%
a = pd.Series(["Thai","French","German"],
             index=["Thailand","France","Germany"],
             name = "Language")
a
# Out:
# Thailand      Thai
# France      French
# Germany     German
# Name: Language, dtype: object

# %%
df["Language"]=a
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count  \
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1
#
#              Language
# Canada            NaN
# France         French
# Germany        German
# Thailand         Thai
# Cuba              NaN
# South Africa      NaN
# Russia            NaN

# %% [markdown]
# #### Dropping columns

# %%
df.drop(columns='Language')
#df.drop(columns='Language', inplace=True) to permenantly remove the column
# Out:
#               Population     GDP  Surface Area    HDI Continent  count
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1

# %% [markdown]
# #### Replacing all values in a column

# %%
df["Language"]="UngaBunga"
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count  \
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1
#
#                Language
# Canada        UngaBunga
# France        UngaBunga
# Germany       UngaBunga
# Thailand      UngaBunga
# Cuba          UngaBunga
# South Africa  UngaBunga
# Russia        UngaBunga

# %% [markdown]
# #### Renaming Columns (immutable)

# %%
df.rename(columns={"HDI":"Human Development Index", "Population":"Pop"},
         index={"Canada":"USA","Cuba":"Mexico"})
# Out:
#                  Pop     GDP  Surface Area  Human Development Index Continent  \
# USA            23.44   18273           210                    0.912   America
# France         54.22  217278         17317                    0.721    Europe
# Germany        77.29   38283          8318                    0.221    Europe
# Thailand       88.82    7446          6573                    0.887      Asia
# Mexico         32.67   73156         81297                    0.220   America
# South Africa   66.66    5471           767                    0.443    Africa
# Russia        777.77    7277           878                    0.412    Europe
#
#               count   Language
# USA               1  UngaBunga
# France            1  UngaBunga
# Germany           1  UngaBunga
# Thailand          1  UngaBunga
# Mexico            1  UngaBunga
# South Africa      1  UngaBunga
# Russia            1  UngaBunga

# %%
df
# Out:
#               Population     GDP  Surface Area    HDI Continent  count  \
# Canada             23.44   18273           210  0.912   America      1
# France             54.22  217278         17317  0.721    Europe      1
# Germany            77.29   38283          8318  0.221    Europe      1
# Thailand           88.82    7446          6573  0.887      Asia      1
# Cuba               32.67   73156         81297  0.220   America      1
# South Africa       66.66    5471           767  0.443    Africa      1
# Russia            777.77    7277           878  0.412    Europe      1
#
#                Language
# Canada        UngaBunga
# France        UngaBunga
# Germany       UngaBunga
# Thailand      UngaBunga
# Cuba          UngaBunga
# South Africa  UngaBunga
# Russia        UngaBunga

# %% [markdown]
# #### Use inplace = True to permanently change

# %%
df.rename(columns={"HDI":"Human Development Index", "Population":"Pop"},
         index={"Canada":"USA","Cuba":"Mexico"},inplace = "True")

# %%
df
# Out:
#                  Pop     GDP  Surface Area  Human Development Index Continent  \
# USA            23.44   18273           210                    0.912   America
# France         54.22  217278         17317                    0.721    Europe
# Germany        77.29   38283          8318                    0.221    Europe
# Thailand       88.82    7446          6573                    0.887      Asia
# Mexico         32.67   73156         81297                    0.220   America
# South Africa   66.66    5471           767                    0.443    Africa
# Russia        777.77    7277           878                    0.412    Europe
#
#               count   Language
# USA               1  UngaBunga
# France            1  UngaBunga
# Germany           1  UngaBunga
# Thailand          1  UngaBunga
# Mexico            1  UngaBunga
# South Africa      1  UngaBunga
# Russia            1  UngaBunga

# %%
df.rename(index=str.upper) #For upper case
# Out:
#                  Pop     GDP  Surface Area  Human Development Index Continent  \
# USA            23.44   18273           210                    0.912   America
# FRANCE         54.22  217278         17317                    0.721    Europe
# GERMANY        77.29   38283          8318                    0.221    Europe
# THAILAND       88.82    7446          6573                    0.887      Asia
# MEXICO         32.67   73156         81297                    0.220   America
# SOUTH AFRICA   66.66    5471           767                    0.443    Africa
# RUSSIA        777.77    7277           878                    0.412    Europe
#
#               count   Language
# USA               1  UngaBunga
# FRANCE            1  UngaBunga
# GERMANY           1  UngaBunga
# THAILAND          1  UngaBunga
# MEXICO            1  UngaBunga
# SOUTH AFRICA      1  UngaBunga
# RUSSIA            1  UngaBunga

# %% [markdown]
# #### Creating columns from other columns

# %%
#To create a new column of GDP/Capita we can - 
df["GDP per Capita"] = df["GDP"]/df["Pop"]
df
# Out:
#                  Pop     GDP  Surface Area  Human Development Index Continent  \
# USA            23.44   18273           210                    0.912   America
# France         54.22  217278         17317                    0.721    Europe
# Germany        77.29   38283          8318                    0.221    Europe
# Thailand       88.82    7446          6573                    0.887      Asia
# Mexico         32.67   73156         81297                    0.220   America
# South Africa   66.66    5471           767                    0.443    Africa
# Russia        777.77    7277           878                    0.412    Europe
#
#               count   Language  GDP per Capita
# USA               1  UngaBunga      779.564846
# France            1  UngaBunga     4007.340465
# Germany           1  UngaBunga      495.316341
# Thailand          1  UngaBunga       83.832470
# Mexico            1  UngaBunga     2239.240894
# South Africa      1  UngaBunga       82.073207
# Russia            1  UngaBunga        9.356236

# %%
#adding GDP and Surface Area
df["Total"]=df.iloc[:,1:3].sum(axis=1)
#(First colon specifies we want all the rows
# To add horizontally we need to specify axis=1)
df.head()
# Out:
#             Pop     GDP  Surface Area  Human Development Index Continent  \
# USA       23.44   18273           210                    0.912   America
# France    54.22  217278         17317                    0.721    Europe
# Germany   77.29   38283          8318                    0.221    Europe
# Thailand  88.82    7446          6573                    0.887      Asia
# Mexico    32.67   73156         81297                    0.220   America
#
#           count   Language  GDP per Capita   Total
# USA           1  UngaBunga      779.564846   18483
# France        1  UngaBunga     4007.340465  234595
# Germany       1  UngaBunga      495.316341   46601
# Thailand      1  UngaBunga       83.832470   14019
# Mexico        1  UngaBunga     2239.240894  154453

# %% [markdown]
# #### Rearranging columns

# %%
#To put total column after surface area
df = df[["Pop","GDP","Surface Area","Total","Human Development Index","Continent","Language","GDP per Capita"]]
df.head()
# Out:
#             Pop     GDP  Surface Area   Total  Human Development Index  \
# USA       23.44   18273           210   18483                    0.912
# France    54.22  217278         17317  234595                    0.721
# Germany   77.29   38283          8318   46601                    0.221
# Thailand  88.82    7446          6573   14019                    0.887
# Mexico    32.67   73156         81297  154453                    0.220
#
#          Continent   Language  GDP per Capita
# USA        America  UngaBunga      779.564846
# France      Europe  UngaBunga     4007.340465
# Germany     Europe  UngaBunga      495.316341
# Thailand      Asia  UngaBunga       83.832470
# Mexico     America  UngaBunga     2239.240894

# %% [markdown]
# #### Creating new rows
# immutable

# %%
df.append(pd.Series({"Population":300,"GDP":212,"Surface Area":2184,"Continent":"Asia"},name="China"))
# Out:
# C:\Users\coloR_\AppData\Local\Temp\ipykernel_2148\2393638649.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(pd.Series({"Population":300,"GDP":212,"Surface Area":2184,"Continent":"Asia"},name="China"))
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# USA            23.44   18273           210   18483.0                    0.912
# France         54.22  217278         17317  234595.0                    0.721
# Germany        77.29   38283          8318   46601.0                    0.221
# Thailand       88.82    7446          6573   14019.0                    0.887
# Mexico         32.67   73156         81297  154453.0                    0.220
# South Africa   66.66    5471           767    6238.0                    0.443
# Russia        777.77    7277           878    8155.0                    0.412
# China            NaN     212          2184       NaN                      NaN
#
#              Continent   Language  GDP per Capita  Population
# USA            America  UngaBunga      779.564846         NaN
# France          Europe  UngaBunga     4007.340465         NaN
# Germany         Europe  UngaBunga      495.316341         NaN
# Thailand          Asia  UngaBunga       83.832470         NaN
# Mexico         America  UngaBunga     2239.240894         NaN
# South Africa    Africa  UngaBunga       82.073207         NaN
# Russia          Europe  UngaBunga        9.356236         NaN
# China             Asia        NaN             NaN       300.0

# %% [markdown]
# permanent

# %%
df.loc["China"]=pd.Series({"Population":300,"GDP":212,"Surface Area":2184,"Continent":"Asia"})
df
# Out:
# C:\Users\coloR_\AppData\Local\Temp\ipykernel_2148\158170995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc["China"]=pd.Series({"Population":300,"GDP":212,"Surface Area":2184,"Continent":"Asia"})
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# USA            23.44   18273           210   18483.0                    0.912
# France         54.22  217278         17317  234595.0                    0.721
# Germany        77.29   38283          8318   46601.0                    0.221
# Thailand       88.82    7446          6573   14019.0                    0.887
# Mexico         32.67   73156         81297  154453.0                    0.220
# South Africa   66.66    5471           767    6238.0                    0.443
# Russia        777.77    7277           878    8155.0                    0.412
# China            NaN     212          2184       NaN                      NaN
#
#              Continent   Language  GDP per Capita
# USA            America  UngaBunga      779.564846
# France          Europe  UngaBunga     4007.340465
# Germany         Europe  UngaBunga      495.316341
# Thailand          Asia  UngaBunga       83.832470
# Mexico         America  UngaBunga     2239.240894
# South Africa    Africa  UngaBunga       82.073207
# Russia          Europe  UngaBunga        9.356236
# China             Asia        NaN             NaN

# %% [markdown]
# #### Dropping rows

# %%
df.drop("China",inplace=True)
# Out:
# C:\Users\coloR_\AppData\Local\Temp\ipykernel_2148\3325931873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("China",inplace=True)

# %%
df
# Out:
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# USA            23.44   18273           210   18483.0                    0.912
# France         54.22  217278         17317  234595.0                    0.721
# Germany        77.29   38283          8318   46601.0                    0.221
# Thailand       88.82    7446          6573   14019.0                    0.887
# Mexico         32.67   73156         81297  154453.0                    0.220
# South Africa   66.66    5471           767    6238.0                    0.443
# Russia        777.77    7277           878    8155.0                    0.412
#
#              Continent   Language  GDP per Capita
# USA            America  UngaBunga      779.564846
# France          Europe  UngaBunga     4007.340465
# Germany         Europe  UngaBunga      495.316341
# Thailand          Asia  UngaBunga       83.832470
# Mexico         America  UngaBunga     2239.240894
# South Africa    Africa  UngaBunga       82.073207
# Russia          Europe  UngaBunga        9.356236

# %% [markdown]
# ### Iterating through rows

# %%
for index, row in df.iterrows():
    print(index,row)
# Out:
# USA Pop                             23.44
# GDP                             18273
# Surface Area                      210
# Total                         18483.0
# Human Development Index         0.912
# Continent                     America
# Language                    UngaBunga
# GDP per Capita             779.564846
# Name: USA, dtype: object
# France Pop                              54.22
# GDP                             217278
# Surface Area                     17317
# Total                         234595.0
# Human Development Index          0.721
# Continent                       Europe
# Language                     UngaBunga
# GDP per Capita             4007.340465
# Name: France, dtype: object
# Germany Pop                             77.29
# GDP                             38283
# Surface Area                     8318
# Total                         46601.0
# Human Development Index         0.221
# Continent                      Europe
# Language                    UngaBunga
# GDP per Capita             495.316341
# Name: Germany, dtype: object
# Thailand Pop                            88.82
# GDP                             7446
# Surface Area                    6573
# Total                        14019.0
# Human Development Index        0.887
# Continent                       Asia
# Language                   UngaBunga
# GDP per Capita              83.83247
# Name: Thailand, dtype: object
# Mexico Pop                              32.67
# GDP                              73156
# Surface Area                     81297
# Total                         154453.0
# Human Development Index           0.22
# Continent                      America
# Language                     UngaBunga
# GDP per Capita             2239.240894
# Name: Mexico, dtype: object
# South Africa Pop                            66.66
# GDP                             5471
# Surface Area                     767
# Total                         6238.0
# Human Development Index        0.443
# Continent                     Africa
# Language                   UngaBunga
# GDP per Capita             82.073207
# Name: South Africa, dtype: object
# Russia Pop                           777.77
# GDP                             7277
# Surface Area                     878
# Total                         8155.0
# Human Development Index        0.412
# Continent                     Europe
# Language                   UngaBunga
# GDP per Capita              9.356236
# Name: Russia, dtype: object

# %% [markdown]
# ### Sorting data

# %%
df.sort_values("Continent",ascending=True)
# Out:
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# South Africa   66.66    5471           767    6238.0                    0.443
# USA            23.44   18273           210   18483.0                    0.912
# Mexico         32.67   73156         81297  154453.0                    0.220
# Thailand       88.82    7446          6573   14019.0                    0.887
# France         54.22  217278         17317  234595.0                    0.721
# Germany        77.29   38283          8318   46601.0                    0.221
# Russia        777.77    7277           878    8155.0                    0.412
#
#              Continent   Language  GDP per Capita
# South Africa    Africa  UngaBunga       82.073207
# USA            America  UngaBunga      779.564846
# Mexico         America  UngaBunga     2239.240894
# Thailand          Asia  UngaBunga       83.832470
# France          Europe  UngaBunga     4007.340465
# Germany         Europe  UngaBunga      495.316341
# Russia          Europe  UngaBunga        9.356236

# %%
df.sort_values(["Continent","GDP"],ascending=True)
# Out:
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# South Africa   66.66    5471           767    6238.0                    0.443
# USA            23.44   18273           210   18483.0                    0.912
# Mexico         32.67   73156         81297  154453.0                    0.220
# Thailand       88.82    7446          6573   14019.0                    0.887
# Russia        777.77    7277           878    8155.0                    0.412
# Germany        77.29   38283          8318   46601.0                    0.221
# France         54.22  217278         17317  234595.0                    0.721
#
#              Continent   Language  GDP per Capita
# South Africa    Africa  UngaBunga       82.073207
# USA            America  UngaBunga      779.564846
# Mexico         America  UngaBunga     2239.240894
# Thailand          Asia  UngaBunga       83.832470
# Russia          Europe  UngaBunga        9.356236
# Germany         Europe  UngaBunga      495.316341
# France          Europe  UngaBunga     4007.340465

# %%
df.sort_values(["Continent","GDP"],ascending=[1,0])
#Ascending for continent and descending for GDP
# Out:
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# South Africa   66.66    5471           767    6238.0                    0.443
# Mexico         32.67   73156         81297  154453.0                    0.220
# USA            23.44   18273           210   18483.0                    0.912
# Thailand       88.82    7446          6573   14019.0                    0.887
# France         54.22  217278         17317  234595.0                    0.721
# Germany        77.29   38283          8318   46601.0                    0.221
# Russia        777.77    7277           878    8155.0                    0.412
#
#              Continent   Language  GDP per Capita
# South Africa    Africa  UngaBunga       82.073207
# Mexico         America  UngaBunga     2239.240894
# USA            America  UngaBunga      779.564846
# Thailand          Asia  UngaBunga       83.832470
# France          Europe  UngaBunga     4007.340465
# Germany         Europe  UngaBunga      495.316341
# Russia          Europe  UngaBunga        9.356236

# %% [markdown]
# ### Lambda Function
# An anonymous function which we can pass in instantly without defining a name or any thing like a full traditional function.
#
# #### lambda x:x
# #### (keyword)(BoundVariable):(Body)

# %%
df.rename(index=lambda x:x.lower())
# Out:
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# usa            23.44   18273           210   18483.0                    0.912
# france         54.22  217278         17317  234595.0                    0.721
# germany        77.29   38283          8318   46601.0                    0.221
# thailand       88.82    7446          6573   14019.0                    0.887
# mexico         32.67   73156         81297  154453.0                    0.220
# south africa   66.66    5471           767    6238.0                    0.443
# russia        777.77    7277           878    8155.0                    0.412
#
#              Continent   Language  GDP per Capita
# usa            America  UngaBunga      779.564846
# france          Europe  UngaBunga     4007.340465
# germany         Europe  UngaBunga      495.316341
# thailand          Asia  UngaBunga       83.832470
# mexico         America  UngaBunga     2239.240894
# south africa    Africa  UngaBunga       82.073207
# russia          Europe  UngaBunga        9.356236

# %% [markdown]
# #### Lambda with apply
# We can use the apply() function to apply the lambda function to both rows and columns of a dataframe

# %%
df["Pop"]=df["Pop"].apply(lambda x:x+100)
df
# Out:
# C:\Users\coloR_\AppData\Local\Temp\ipykernel_2148\1260170666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Pop"]=df["Pop"].apply(lambda x:x+100)
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# USA           123.44   18273           210   18483.0                    0.912
# France        154.22  217278         17317  234595.0                    0.721
# Germany       177.29   38283          8318   46601.0                    0.221
# Thailand      188.82    7446          6573   14019.0                    0.887
# Mexico        132.67   73156         81297  154453.0                    0.220
# South Africa  166.66    5471           767    6238.0                    0.443
# Russia        877.77    7277           878    8155.0                    0.412
#
#              Continent   Language  GDP per Capita
# USA            America  UngaBunga      779.564846
# France          Europe  UngaBunga     4007.340465
# Germany         Europe  UngaBunga      495.316341
# Thailand          Asia  UngaBunga       83.832470
# Mexico         America  UngaBunga     2239.240894
# South Africa    Africa  UngaBunga       82.073207
# Russia          Europe  UngaBunga        9.356236

# %% [markdown]
# #### Conditional statements using Lambda

# %%
df["Size"]=df["Pop"].apply(lambda x:"Big"if x>150 else "Small")

# %%
df
# Out:
#                  Pop     GDP  Surface Area     Total  Human Development Index  \
# USA           123.44   18273           210   18483.0                    0.912
# France        154.22  217278         17317  234595.0                    0.721
# Germany       177.29   38283          8318   46601.0                    0.221
# Thailand      188.82    7446          6573   14019.0                    0.887
# Mexico        132.67   73156         81297  154453.0                    0.220
# South Africa  166.66    5471           767    6238.0                    0.443
# Russia        877.77    7277           878    8155.0                    0.412
#
#              Continent   Language  GDP per Capita   Size
# USA            America  UngaBunga      779.564846  Small
# France          Europe  UngaBunga     4007.340465    Big
# Germany         Europe  UngaBunga      495.316341    Big
# Thailand          Asia  UngaBunga       83.832470    Big
# Mexico         America  UngaBunga     2239.240894  Small
# South Africa    Africa  UngaBunga       82.073207    Big
# Russia          Europe  UngaBunga        9.356236    Big

# %% [markdown]
# ### Saving our DataFrame
# #### To csv

# %%
#df.to_csv("modified.csv")
#To remove index
#df.to_csv("modified.csv",index=False)

# %% [markdown]
# #### To Excel

# %%
#df.to_excel("modified.xlsx",index=False)

# %% [markdown]
# #### To text

# %%
#df.to_csv("modified.txt",index=False,sep="\t")
#If \t is not used it is sperated by default by commas(,)
